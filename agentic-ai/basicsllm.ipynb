# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDrOTwtMMCPore8ScJWGbEPvQrjUCobl58"

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print(" ADK components imported successfully.")
# Out:
#  ADK components imported successfully.

# %% [markdown]
# INITIALISE

# %%
llm = Gemini(model_name="gemini-1.5-flash")

search_tool = google_search

# %%
my_agent = Agent(
    name="my_first_agent",
    model=llm,
    instruction="You are a helpful assistant who answers briefly.",
    tools=[google_search],
    
)

# %%
agent = Agent(
    name="my_agent",
    model=llm,
    tools=[search_tool],
    instruction="You are a helpful assistant who answers briefly."
)
response = await runner.run_debug(
    "What is the weather in mumbai right now and how can you tell me this "
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13/1202875389.py in <cell line: 1>()
#       5     instruction="You are a helpful assistant who answers briefly."
#       6 )
# ----> 7 response = await runner.run_debug(
#       8     "What is the weather in mumbai right now and how can you tell me this "
#       9 )
#
# NameError: name 'runner' is not defined

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
url_prefix = get_adk_proxy_url()
# !adk web --url_prefix {url_prefix}
